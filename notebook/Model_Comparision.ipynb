# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_colwidth', None)  # Show full content in each cell
pd.set_option('display.width', 1000)  # Set max width

# %% [markdown]
# # Supervised Model

# %% [markdown]
# ## Motion Classifier

# %%
# Define models and values
models = {
    "Random Forest": [0.97, 0.97 , 0.97 , 2.8],
    "Decision Tree": [0.97, 0.97, 0.97, 0.65],
    "LinearSVC": [0.7, 0.7, 0.7, 0.005]
}
metrics = ["Accuracy" , "Precision", "Recall", "Model Size(in 100KB)"]

# Convert to radians
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]  # Complete the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plot each model
for model, values in models.items():
    values += values[:1]  # Close the loop
    ax.plot(angles, values, label=model, linewidth=2)
    ax.fill(angles, values, alpha=0.25)  # Fill area

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
plt.title("Motion Classifier Comparison - Radar Plot")
plt.show()

# %% [markdown]
# ## Steady Movement Classification

# %%
# Define models and values
models = {
    "Random Forest": [0.91, 0.91 , 0.91 , 4.5],
    "Decision Tree": [0.9, 0.9 , 0.9 , 1],
    "LinearSVC": [0.58, 0.57, 0.55, 0.012]
}
metrics = ["Accuracy" , "Precision", "Recall", "Model Size(in 100KB)"]

# Convert to radians
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]  # Complete the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plot each model
for model, values in models.items():
    values += values[:1]  # Close the loop
    ax.plot(angles, values, label=model, linewidth=2)
    ax.fill(angles, values, alpha=0.25)  # Fill area

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
plt.title("Steady Movement Classifier Comparison - Radar Plot")
plt.show()

# %% [markdown]
# ## Unsteady Movement Classification

# %%
# Define models and values
models = {
    "Random Forest": [0.85, 0.85 , 0.85 , 3.3],
    "Decision Tree": [0.85, 0.85 , 0.85, 1],
    "LinearSVC": [0.62, 0.62, 0.62, 0.005]
}
metrics = ["Accuracy" , "Precision", "Recall", "Model Size(in 100KB)"]

# Convert to radians
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]  # Complete the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plot each model
for model, values in models.items():
    values += values[:1]  # Close the loop
    ax.plot(angles, values, label=model, linewidth=2)
    ax.fill(angles, values, alpha=0.25)  # Fill area

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
plt.title("Unsteady Movement Classifier Comparison - Radar Plot")
plt.show()

# %% [markdown]
# ## Staircase Movement Classification

# %%
# Define models and values
models = {
    "Random Forest": [0.92, 0.92 , 0.92 , 2.8],
    "Decision Tree": [0.92, 0.92 , 0.92 , 0.75],
    "LinearSVC": [0.69, 0.69, 0.68, 0.005]
}
metrics = ["Accuracy" , "Precision", "Recall", "Model Size(in 100KB)"]

# Convert to radians
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]  # Complete the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plot each model
for model, values in models.items():
    values += values[:1]  # Close the loop
    ax.plot(angles, values, label=model, linewidth=2)
    ax.fill(angles, values, alpha=0.25)  # Fill area

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
plt.title("Staircase Movement Classifier Comparison - Radar Plot")
plt.show()

# %% [markdown]
# ## Surface Movement Classification

# %%
# Define models and values
models = {
    "Random Forest": [0.98, 0.98 , 0.98 , 2.1],
    "Decision Tree": [0.98, 0.98 , 0.98, 0.4],
    "LinearSVC": [0.77, 0.78 , 0.76, 0.005]
}
metrics = ["Accuracy" , "Precision", "Recall", "Model Size(in 100KB)"]

# Convert to radians
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]  # Complete the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plot each model
for model, values in models.items():
    values += values[:1]  # Close the loop
    ax.plot(angles, values, label=model, linewidth=2)
    ax.fill(angles, values, alpha=0.25)  # Fill area

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
plt.title("Surface Movement Classifier Comparison - Radar Plot")
plt.show()
